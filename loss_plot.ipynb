# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
f1_80 = [
    0.0118, 0.0330, 0.1347, 0.8063, 0.7884, 0.7283, 0.7242, 0.7030, 0.7043, 0.7142,
    0.7127, 0.7166, 0.7109, 0.7076, 0.6979, 0.7069, 0.6976, 0.7020, 0.7098, 0.7107,
    0.7022, 0.7011, 0.7130, 0.7167, 0.7007, 0.7101, 0.7116, 0.7120, 0.7061, 0.7079
]
f1_90 = [
    0.0067, 0.0075, 0.0215, 0.8450, 0.7705, 0.6676, 0.6086, 0.5638, 0.5729, 0.5555,
    0.5566, 0.5505, 0.5530, 0.5647, 0.5568, 0.5543, 0.5555, 0.5596, 0.5559, 0.5516,
    0.5541, 0.5486, 0.5517, 0.5597, 0.5577, 0.5502, 0.5539, 0.5485, 0.5458, 0.5558
]

# %%
# Plot the trend of f1 scores for both f1_80 and f1_90 on the same graph
plt.figure(figsize=(10, 5))
plt.plot(range(1, 31), f1_80, marker='o', label='80% Noise')
plt.plot(range(1, 31), f1_90, marker='x', label='90% Noise')
plt.axvline(x=3, color='red', linestyle='--', label='Epoch 3')

plt.title('Trend in F1 Scores at 80% and 90% noise level after noisy learning fix')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.xticks(range(1, 31))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
f1_20 = [
    0.9258, 0.9304, 0.9231, 0.9086, 0.9220, 0.9242, 0.9242, 0.9221, 0.9229, 0.9231,
    0.9203, 0.9242, 0.9251, 0.9250, 0.9249, 0.9239, 0.9214, 0.9243, 0.9227, 0.9240,
    0.9217, 0.9257, 0.9223, 0.9243, 0.9241, 0.9254, 0.9255, 0.9241, 0.9255, 0.9250
]

f1_50 = [
    0.8987, 0.9083, 0.8351, 0.9082, 0.9071, 0.9024, 0.8972, 0.8869, 0.8854, 0.8850,
    0.8775, 0.8722, 0.8731, 0.8633, 0.8652, 0.8638, 0.8663, 0.8668, 0.8726, 0.8657,
    0.8658, 0.8704, 0.8710, 0.8657, 0.8679, 0.8638, 0.8681, 0.8652, 0.8701, 0.8703
]

f1_70 = [
    0.7971, 0.7195, 0.4420, 0.8264, 0.8389, 0.8342, 0.8436, 0.8409, 0.8423, 0.8390,
    0.8399, 0.8413, 0.8390, 0.8356, 0.8412, 0.8361, 0.8350, 0.8366, 0.8359, 0.8238,
    0.8384, 0.8410, 0.8420, 0.8357, 0.8392, 0.8374, 0.8374, 0.8379, 0.8387, 0.8438
]

f1_reddit = [
    0.7261, 0.7026, 0.6925, 0.7295, 0.7423, 0.7211, 0.7252, 0.7468, 0.7596, 0.7340,
    0.7683, 0.7339, 0.7682, 0.7554, 0.7340, 0.7681, 0.7724, 0.7640, 0.7769, 0.7594,
    0.7683, 0.7510, 0.7553, 0.7511, 0.7632, 0.7466, 0.7597, 0.7511, 0.7468, 0.7511
]

# %%
# Plot the trend of f1 scores for both f1_80 and f1_90 on the same graph
plt.figure(figsize=(10, 5))
plt.plot(range(1, 31), f1_20, marker='o', label='20% Noise')
plt.plot(range(1, 31), f1_50, marker='x', label='50% Noise')
plt.plot(range(1, 31), f1_70, marker='s', label='70% Noise')
plt.plot(range(1, 31), f1_reddit, marker='^', label='Reddit')

plt.title('Trend in F1 Scores at various noise levels training on AG News and Reddit datasets')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.xticks(range(1, 31))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
