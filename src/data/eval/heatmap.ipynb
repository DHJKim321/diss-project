# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # XGBoost RF on Shape Test Data

# %%
xgboost = pd.read_csv('evaluated_shape_xgboost_rf.csv')

# %%
y_true_xgboost = xgboost['label']
y_pred_xgboost = xgboost['predictions']

cm = confusion_matrix(y_true_xgboost, y_pred_xgboost)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
# Create a labeled heatmap
labels = ['Negative', 'Positive']  # or [0, 1] depending on preference
sns.set(style='whitegrid')

plt.figure(figsize=(6, 5))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='YlGnBu',
            xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix Heatmap (XGBoost RF on Shape Data)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # BERT on Shape Test Data

# %%
bert = pd.read_csv('evaluated_shape_bert-base-uncased.csv')

# %%
y_true_bert = bert['label']
y_pred_bert = bert['predictions']
cm = confusion_matrix(y_true_bert, y_pred_bert)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
# Create a labeled heatmap
labels = ['Negative', 'Positive']  # or [0, 1] depending on preference
sns.set(style='whitegrid')
plt.figure(figsize=(6, 5))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='YlGnBu',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix Heatmap (BERT on Shape Data)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mistral on Shape Test Data

# %%
mistral = pd.read_csv('evaluated_shape_mistral.csv')

# %%
mistral_preds = mistral['predictions']

# %%
y_true_mistral = mistral['label']
y_pred_mistral = mistral['predictions']
cm = confusion_matrix(y_true_mistral, y_pred_mistral)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
labels = ['Negative', 'Positive']
sns.set(style='whitegrid')
plt.figure(figsize=(6, 5))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='YlGnBu',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix Heatmap (Mistral on Shape Data)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # BERT (GMM Label Denoising)

# %%
gmm_bert = pd.read_csv('evaluated_shape_bert-base-uncased_umap_gmm_denoised.csv')
y_true_gmm_bert = gmm_bert['label']
y_pred_gmm_bert = gmm_bert['predictions']
cm = confusion_matrix(y_true_gmm_bert, y_pred_gmm_bert)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
labels = ['Negative', 'Positive']
sns.set(style='whitegrid')
plt.figure(figsize=(6, 5))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='YlGnBu',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix Heatmap (GMM BERT on Shape Data)')
plt.tight_layout()
plt.show()
