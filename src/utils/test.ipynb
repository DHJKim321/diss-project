# %%
import pandas as pd
import numpy as np
import torch
import pickle
from tqdm import tqdm_notebook as tqdm
import os
import re
import pickle

# %%
device = torch.device("mps")

# %%
# Load translation model
en2ru = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.en-ru.single_model', tokenizer='moses', bpe='fastbpe', force_reload=True)
ru2en = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.ru-en.single_model', tokenizer='moses', bpe='fastbpe', force_reload=True)
# Out:
# Downloading: "https://github.com/pytorch/fairseq/zipball/main" to /Users/danielkim/.cache/torch/hub/main.zip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load translation model
# ----> 2 en2ru = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.en-ru.single_model', tokenizer='moses', bpe='fastbpe', force_reload=True)
#       3 ru2en = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.ru-en.single_model', tokenizer='moses', bpe='fastbpe', force_reload=True)
#
# File /opt/anaconda3/envs/diss/lib/python3.10/site-packages/torch/hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
#     638     repo_or_dir = _get_cache_or_reload(
#     639         repo_or_dir,
#     640         force_reload,
#    (...)
# ...
